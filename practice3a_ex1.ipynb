# %%
from transformers import pipeline

# %%
sentiment_analyzer = pipeline(
    "sentiment-analysis",
    model="distilbert-base-uncased-finetuned-sst-2-english",
    framework="pt"  # <- ép dùng PyTorch
)
# Out:
# Device set to use cpu

# %%
text = [
    "I love playing and watching cricket!",
    "I hate when virat Kohli misses a century"
]

results = sentiment_analyzer(text)  # dùng đúng tên biến
for result in results:
    print(result)
# Out:
# {'label': 'POSITIVE', 'score': 0.999704897403717}
# {'label': 'NEGATIVE', 'score': 0.9990317821502686}
